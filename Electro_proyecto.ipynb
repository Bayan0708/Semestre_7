# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Datos de la tabla
data = {
    "Pulsera Inteligente": [85, 82, 83, 81, 80, 85, 84, 83, 83, 83],
    "Proyecto": [88, 83, 85, 85, 86, 95, 90, 85, 84, 87]
}

# Crear un DataFrame
df = pd.DataFrame(data)

# Cálculo de promedios
prom_pulsera = df["Pulsera Inteligente"].mean()
prom_proyecto = df["Proyecto"].mean()

# Cálculo de desviación estándar
std_pulsera = df["Pulsera Inteligente"].std()
std_proyecto = df["Proyecto"].std()

# Mostrar resultados
print(f"Promedio Pulsera Inteligente: {prom_pulsera:.2f}, Desviación estándar: {std_pulsera:.2f}")
print(f"Promedio Proyecto: {prom_proyecto:.2f}, Desviación estándar: {std_proyecto:.2f}")

# Visualización
plt.figure(figsize=(10, 6))
plt.plot(df["Pulsera Inteligente"], label="Pulsera Inteligente", marker="o")
plt.plot(df["Proyecto"], label="Proyecto", marker="o")
plt.axhline(prom_pulsera, color="blue", linestyle="--", label="Promedio Pulsera")
plt.axhline(prom_proyecto, color="orange", linestyle="--", label="Promedio Proyecto")
plt.title("Comparación del Pulso Cardiaco [rpm]")
plt.xlabel("Medición")
plt.ylabel("Pulso [rpm]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Promedio Pulsera Inteligente: 82.90, Desviación estándar: 1.60
# Promedio Proyecto: 86.80, Desviación estándar: 3.52

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Datos de la tabla 2: Medición de respiración en reposo
data_respiracion = {
    "Pulsera Inteligente": [93, 95, 97, 96, 95, 96, 94, 94, 97, 94],
    "Proyecto": [94, 95, 96, 98, 96, 95, 97, 96, 96, 94]
}

# Crear DataFrame
df_respiracion = pd.DataFrame(data_respiracion)

# Cálculo de promedios
prom_pulsera_resp = df_respiracion["Pulsera Inteligente"].mean()
prom_proyecto_resp = df_respiracion["Proyecto"].mean()

# Cálculo de desviación estándar
std_pulsera_resp = df_respiracion["Pulsera Inteligente"].std()
std_proyecto_resp = df_respiracion["Proyecto"].std()

# Mostrar resultados
print(f"Promedio Pulsera Inteligente: {prom_pulsera_resp:.2f}, Desviación estándar: {std_pulsera_resp:.2f}")
print(f"Promedio Proyecto: {prom_proyecto_resp:.2f}, Desviación estándar: {std_proyecto_resp:.2f}")

# Visualización
plt.figure(figsize=(10, 6))
plt.plot(df_respiracion["Pulsera Inteligente"], label="Pulsera Inteligente", marker="o", color='blue')
plt.plot(df_respiracion["Proyecto"], label="Proyecto", marker="o", color='orange')
plt.axhline(prom_pulsera_resp, color="blue", linestyle="--", label=f"Promedio Pulsera: {prom_pulsera_resp:.1f}")
plt.axhline(prom_proyecto_resp, color="orange", linestyle="--", label=f"Promedio Proyecto: {prom_proyecto_resp:.1f}")
plt.title("Comparación de la Medición de Respiración en Reposo [%]")
plt.xlabel("Medición")
plt.ylabel("Respiración [%]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Promedio Pulsera Inteligente: 95.10, Desviación estándar: 1.37
# Promedio Proyecto: 95.70, Desviación estándar: 1.25

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos de la Tabla 3: Medición del pulso cardiaco en actividad ligera
data_pulso_actividad = {
    "Pulsera Inteligente": [125, 113, 114, 119, 131, 132, 105, 98, 113, 127],
    "Proyecto": [119, 117, 101, 113, 127, 122, 112, 103, 108, 119]
}

# Crear DataFrame
df_pulso_actividad = pd.DataFrame(data_pulso_actividad)

# Cálculo de promedios
prom_pulsera_actividad = df_pulso_actividad["Pulsera Inteligente"].mean()
prom_proyecto_actividad = df_pulso_actividad["Proyecto"].mean()

# Cálculo de desviación estándar
std_pulsera_actividad = df_pulso_actividad["Pulsera Inteligente"].std()
std_proyecto_actividad = df_pulso_actividad["Proyecto"].std()

# Mostrar resultados
print(f"Promedio Pulsera Inteligente: {prom_pulsera_actividad:.2f}, Desviación estándar: {std_pulsera_actividad:.2f}")
print(f"Promedio Proyecto: {prom_proyecto_actividad:.2f}, Desviación estándar: {std_proyecto_actividad:.2f}")

# Visualización
plt.figure(figsize=(10, 6))
plt.plot(df_pulso_actividad["Pulsera Inteligente"], label="Pulsera Inteligente", marker="o", color='blue')
plt.plot(df_pulso_actividad["Proyecto"], label="Proyecto", marker="o", color='orange')
plt.axhline(prom_pulsera_actividad, color="blue", linestyle="--", label=f"Promedio Pulsera: {prom_pulsera_actividad:.1f}")
plt.axhline(prom_proyecto_actividad, color="orange", linestyle="--", label=f"Promedio Proyecto: {prom_proyecto_actividad:.1f}")
plt.title("Comparación del Pulso Cardiaco en Actividad Ligera [rpm]")
plt.xlabel("Medición")
plt.ylabel("Pulso [rpm]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Promedio Pulsera Inteligente: 117.70, Desviación estándar: 11.21
# Promedio Proyecto: 114.10, Desviación estándar: 8.32

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos de la Tabla 4: Medición de respiración en reposo
data_respiracion_reposo = {
    "Pulsera Inteligente": [98, 96, 96, 97, 96, 97, 97, 98, 94, 97],
    "Proyecto": [95, 96, 94, 95, 97, 96, 95, 98, 95, 96]
}

# Crear DataFrame
df_respiracion_reposo = pd.DataFrame(data_respiracion_reposo)

# Cálculo de promedios
prom_pulsera_respiracion = df_respiracion_reposo["Pulsera Inteligente"].mean()
prom_proyecto_respiracion = df_respiracion_reposo["Proyecto"].mean()

# Cálculo de desviación estándar
std_pulsera_respiracion = df_respiracion_reposo["Pulsera Inteligente"].std()
std_proyecto_respiracion = df_respiracion_reposo["Proyecto"].std()

# Mostrar resultados
print(f"Promedio Pulsera Inteligente: {prom_pulsera_respiracion:.2f}, Desviación estándar: {std_pulsera_respiracion:.2f}")
print(f"Promedio Proyecto: {prom_proyecto_respiracion:.2f}, Desviación estándar: {std_proyecto_respiracion:.2f}")

# Visualización
plt.figure(figsize=(10, 6))
plt.plot(df_respiracion_reposo["Pulsera Inteligente"], label="Pulsera Inteligente", marker="o", color='blue')
plt.plot(df_respiracion_reposo["Proyecto"], label="Proyecto", marker="o", color='orange')
plt.axhline(prom_pulsera_respiracion, color="blue", linestyle="--", label=f"Promedio Pulsera: {prom_pulsera_respiracion:.1f}")
plt.axhline(prom_proyecto_respiracion, color="orange", linestyle="--", label=f"Promedio Proyecto: {prom_proyecto_respiracion:.1f}")
plt.title("Comparación de la Medición de Respiración en Reposo [%]")
plt.xlabel("Medición")
plt.ylabel("Respiración [%]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Promedio Pulsera Inteligente: 96.60, Desviación estándar: 1.17
# Promedio Proyecto: 95.70, Desviación estándar: 1.16
